# %% [markdown]
# ## Book 3: Analyzing Neighborhoods in Toronto, Canada using Foursquare

# %% [markdown]
# Peer-graded assignment for IBM Data Science Professional certification capstone course: Week 3 - Brian Vineyard
#
# **Tools used**:
# - [BeautifulSoup](https://https://beautiful-soup-4.readthedocs.io/en/latest/)
# - [Foursquare API tool](https://foursquare.com)
# - [http://cocl.us/Geospatial_data](http://cocl.us/Geospatial_data)
#
# Toronto neighborhoods information is loaded using postal codes pulled from Wikipedia using BeautifulSoup, then analyzed using the Foursquare API tool.
#
# This project uses the following Wiki page: [List of postal codes of Canada: M](https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M)
#
# ### Steps to analyze Toronto Neighborhood Data
#
# 1. Load the wiki containing postal codes for Toronto beginning with the letter 'M' into a Pandas dataframe. BeautifulSoup is used to scrape the wiki for the postal data.
# 2. The data is cleaned up for processing.
# 3. Load the Geospatial data from a .CSV file built from [http://cocl.us/Geospatial_data](http://cocl.us/Geospatial_data). This provides latitude and longitude parameters to use in Foursquare.
# 4. Build out the dataframe with the Toronto neighborhoods including the map coordinates.
# 5. Analyze and model the data to gain insights into neighborhood characteristics.
#
# **This notebook includes the prior work for phase 1 and 2, and new steps for phase 3, analyzing Toronto neighborhoods using the Foursquare API.

# %% [markdown]
# ## <font color="green"> Phase 1 - Build pandas dataframe using BeautifulSoup</font>  ##

# %%
# Import Pandas and Beautiful Soup libraries
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# ### Link to source data and parsing of Wiki website using BeautifulSoup

# %%
# Use Beautiful Soup to get the postal code data from the wiki page
sourcelink = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
source = requests.get(sourcelink).text
Postal_Info = BeautifulSoup(source, 'lxml')

# %% [markdown]
# ### Set up Pandas dataframe to hold postal data

# %%
# Build dataframe with postal data
Column_Names = ['PostalCode','Borough','Neighborhood']
Postal_Data = pd.DataFrame(columns=Column_Names)

# %% [markdown]
# ### Initialize variables for postal code, borough, and neighborhood, then loop through table rows to pull data

# %%
content = Postal_Info.find('div', class_='mw-parser-output')
postal_table = content.table.tbody
postal_code = 0
borough = 0
neighborhood = 0

for tr in postal_table.find_all('tr'):
    i = 0
    for td in tr.find_all('td'):
        if i == 0:
            postal_code = td.text
            i = i + 1
        elif i == 1:
            borough = td.text
            i = i + 1
        elif i == 2:
            neighborhood = td.text.strip('\n').replace(']','')
            Postal_Data = Postal_Data.append({'Postalcode': postal_code,'Borough': borough,'Neighborhood': neighborhood},ignore_index=True)

# %%
Postal_Data.head()
# Out:
#   PostalCode           Borough      Neighborhood Postalcode
# 0        NaN      Not assigned      Not assigned        M1A
# 1        NaN      Not assigned      Not assigned        M2A
# 2        NaN        North York         Parkwoods        M3A
# 3        NaN        North York  Victoria Village        M4A
# 4        NaN  Downtown Toronto      Harbourfront        M5A

# %% [markdown]
# ## Data cleaning - remove boroughs with 'Not assigned',  0 values

# %%
Postal_Data = Postal_Data[Postal_Data.Borough!='Not assigned']
Postal_Data = Postal_Data[Postal_Data.Borough!= 0]
Postal_Data.reset_index(drop = True, inplace = True)
i = 0
for i in range(0,Postal_Data.shape[0]):
    if Postal_Data.iloc[i][2] == 'Not assigned':
        Postal_Data.iloc[i][2] = Postal_Data.iloc[i][1]
        i = i+1
df = Postal_Data.groupby(['Postalcode','Borough'])['Neighborhood'].apply(', '.join).reset_index()

# %%
df = df.dropna()
empty = 'Not assigned'
df = df[(df.Postalcode != empty ) & (df.Borough != empty) & (df.Neighborhood != empty)]

# %% [markdown]
# ### Get first 5 and last 5 rows of data from the postal dataframe

# %%
df.head()
# Out:
#   Postalcode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %%
df.tail()
# Out:
#     Postalcode    Borough                                       Neighborhood
# 98         M9N       York                                             Weston
# 99         M9P  Etobicoke                                          Westmount
# 100        M9R  Etobicoke  Kingsview Village, Martin Grove Gardens, Richv...
# 101        M9V  Etobicoke  Albion Gardens, Beaumond Heights, Humbergate, ...
# 102        M9W  Etobicoke                                          Northwest

# %% [markdown]
# ### Group data by Postal Code and Borough

# %%
def neighborhood_list(grouped):
    return ', '.join(sorted(grouped['Neighborhood'].tolist()))
grp = df.groupby(['Postalcode', 'Borough'])
df2 = grp.apply(neighborhood_list).reset_index(name='Neighborhood')

# %%
print(df2.shape)
df2.head()
# Out:
# (103, 3)
#   Postalcode      Borough                            Neighborhood
# 0        M1B  Scarborough                          Rouge, Malvern
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill
# 3        M1G  Scarborough                                  Woburn
# 4        M1H  Scarborough                               Cedarbrae

# %% [markdown]
# ## <font color="green"> Phase 2 - Add map coordinates for Toronto neighborhoods based on Geospatial data</font>  ##

# %% [markdown]
# ### Load Geospatial data from .csv file built on data from http://cocl.us/Geospatial_data ###

# %%
df3 = pd.read_csv('C:/users/brian/coordinates.csv', delimiter="|")
df3.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# ### Join two dataframes into combined set including coordinates, then view first 5 rows ###

# %%
neighborhood_coords = [df2, df3]
neighborhood_df = pd.concat(neighborhood_coords, axis=1)

# %%
neighborhood_df.head()
# Out:
#   Postalcode      Borough                            Neighborhood Postal Code  \
# 0        M1B  Scarborough                          Rouge, Malvern         M1B
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union         M1C
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill         M1E
# 3        M1G  Scarborough                                  Woburn         M1G
# 4        M1H  Scarborough                               Cedarbrae         M1H
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %% [markdown]
# ### Remove the duplicate 'Postal Code' column, and view head of combined dataframe ###

# %%
del neighborhood_df['Postal Code']

# %%
neighborhood_df.head()
# Out:
#   Postalcode      Borough                            Neighborhood   Latitude  \
# 0        M1B  Scarborough                          Rouge, Malvern  43.806686
# 1        M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2        M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3        M1G  Scarborough                                  Woburn  43.770992
# 4        M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %% [markdown]
# ### Build map of Toronto, Canada showing the neighborhoods from the dataframe ###

# %%
print('The dataframe has {} boroughs and {} neighborhoods.' .format(len(neighborhood_df['Borough'].unique()), neighborhood_df.shape[0]))
# Out:
# The dataframe has 11 boroughs and 103 neighborhoods.

# %%
address = 'Toronto, Canada'
geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto, Canada are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto, Canada are 43.653963, -79.387207.

# %%
# create map of Toronto using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)
# add markers to map
for lat, lng, borough, neighborhood in zip(neighborhood_df['Latitude'], neighborhood_df['Longitude'], neighborhood_df['Borough'], neighborhood_df['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_toronto)
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## <font color="green"> Phase 3 - Analyze Toronto neighborhoods using the Foursquare API</font>  ##

# %% [markdown]
# ### Import libraries ###

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json # library to handle JSON files

from geopy.geocoders import Nominatim 
import requests # library to handle requests
from pandas.io.json import json_normalize
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library
print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Load Foursquare parameters ###

# %%
file = open('credentials.p', 'rb')
credentials = pickle.load(file)
file.close()
CLIENT_ID = credentials['CLIENT_ID']
CLIENT_SECRET = credentials['CLIENT_SECRET']
VERSION = '20180604'
LIMIT = 30

# %% [markdown]
# ### Convert address info for the Doubletree Hotel in downtown Toronto to latitude and longitude coordinates ###

# %%
address = '108 Chestnut St, Toronto, ON'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 43.6546682 -79.38609661430215

# %% [markdown]
# ### Set query paramaters to search for restaurants close by the hotel ###

# %%
search_query = 'Restaurant'
radius = 500
print(search_query + ' .....OK!')
# Out:
# Restaurant .....OK!

# %%
# Set up the search url to query Foursquare
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)

# %%
# Get the results as a JSON file
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e290698edbcad001b806141'},
#  'response': {'venues': [{'id': '4ad4c05ff964a52048f720e3',
#     'name': 'Hemispheres Restaurant & Bistro',
#     'location': {'address': '110 Chestnut Street',
#      'lat': 43.65488413420439,
#      'lng': -79.38593077371578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65488413420439,
#        'lng': -79.38593077371578}],
#      'distance': 27,
#      'postalCode': 'M5G 1R3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['110 Chestnut Street',
#       'Toronto ON M5G 1R3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4ae4b055f964a520229d21e3',
#     'name': 'Kyoto House Japanese Restaurant',
#     'location': {'address': '143 Dundas St. West',
#      'lat': 43.65538110598594,
#      'lng': -79.38527010094231,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65538110598594,
#        'lng': -79.38527010094231}],
#      'distance': 103,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['143 Dundas St. West', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '52a7ae41498eed3af4d0a3fa',
#     'name': 'Yueh Tung Chinese Restaurant',
#     'location': {'address': '126 Elizabeth St.',
#      'crossStreet': 'Dundas St.',
#      'lat': 43.655281263429195,
#      'lng': -79.3853365267765,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655281263429195,
#        'lng': -79.3853365267765}],
#      'distance': 91,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['126 Elizabeth St. (Dundas St.)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4b2027b5f964a520f82d24e3',
#     'name': 'Hong Shing Chinese Restaurant',
#     'location': {'address': '195 Dundas St W',
#      'crossStreet': 'at University Ave',
#      'lat': 43.65492521335936,
#      'lng': -79.38708916106386,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65492521335936,
#        'lng': -79.38708916106386}],
#      'distance': 84,
#      'postalCode': 'M5G 1C7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['195 Dundas St W (at University Ave)',
#       'Toronto ON M5G 1C7',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '60327598'},
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4b295e10f964a520ba9d24e3',
#     'name': 'Richtree Natural Market Restaurants',
#     'location': {'address': '14 Queen St W',
#      'lat': 43.652614361741726,
#      'lng': -79.38023131683906,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652614361741726,
#        'lng': -79.38023131683906}],
#      'distance': 524,
#      'postalCode': 'M5H 3X4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['14 Queen St W', 'Toronto ON M5H 3X4', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4c476d6719fde21e32410876',
#     'name': 'Cali Restaurant',
#     'location': {'address': '179 Dundas St. W.',
#      'crossStreet': 'at Chestnut',
#      'lat': 43.65506808,
#      'lng': -79.386375,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65506808,
#        'lng': -79.386375}],
#      'distance': 49,
#      'postalCode': 'M5G',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['179 Dundas St. W. (at Chestnut)',
#       'Toronto ON M5G',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'shortName': 'Vietnamese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4c69740b8d22c9284d42b745',
#     'name': 'Wah Too Seafood Restaurant',
#     'location': {'address': '56 Centre Ave.',
#      'lat': 43.65483285234745,
#      'lng': -79.38720597193928,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65483285234745,
#        'lng': -79.38720597193928}],
#      'distance': 91,
#      'postalCode': 'M5G 1R5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['56 Centre Ave.', 'Toronto ON M5G 1R5', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '50ca02c0245f2d4aa8c2b313',
#     'name': 'Tundra Restaurant',
#     'location': {'address': '145 Richmond Street West',
#      'crossStreet': 'Hilton Toronto',
#      'lat': 43.650009987649646,
#      'lng': -79.38560774268629,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650009987649646,
#        'lng': -79.38560774268629}],
#      'distance': 520,
#      'postalCode': 'M5H 2L2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['145 Richmond Street West (Hilton Toronto)',
#       'Toronto ON M5H 2L2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4b2a674ef964a52074a824e3',
#     'name': 'New Treasure Restaurant',
#     'location': {'address': '150 Dundas St W',
#      'crossStreet': 'at Elizabeth',
#      'lat': 43.65538444237565,
#      'lng': -79.3853618106867,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65538444237565,
#        'lng': -79.3853618106867}],
#      'distance': 99,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['150 Dundas St W (at Elizabeth)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'shortName': 'Dim Sum',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '5a8b24b2018cbb6c4ca70dae',
#     'name': 'Hendricks Restaurant & Bar',
#     'location': {'address': 'Yonge And Queen',
#      'lat': 43.65341542752959,
#      'lng': -79.37969842137554,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65341542752959,
#        'lng': -79.37969842137554}],
#      'distance': 533,
#      'postalCode': 'M5G 2H6',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Yonge And Queen', 'Toronto ON M5G 2H6', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4ad4c060f964a52070f720e3',
#     'name': 'Adega Restaurant',
#     'location': {'address': '33 Elm St',
#      'crossStreet': 'at Bay St',
#      'lat': 43.65751886446546,
#      'lng': -79.38346181502347,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65751886446546,
#        'lng': -79.38346181502347}],
#      'distance': 381,
#      'postalCode': 'M5G 1H1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['33 Elm St (at Bay St)',
#       'Toronto ON M5G 1H1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '56dd9d68498eb4e5edcb30f9',
#     'name': 'Spring Rolls | Japanese Restaurant in Toronto',
#     'location': {'address': '40 Dundas St W Box 36,',
#      'lat': 43.65610515821675,
#      'lng': -79.38349485397339,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65610515821675,
#        'lng': -79.38349485397339}],
#      'distance': 263,
#      'postalCode': 'M5G 2C2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['40 Dundas St W Box 36,',
#       'Toronto ON M5G 2C2',
#       'Canada']},
#     'categories': [{'id': '56aa371be4b08b9a8d573538',
#       'name': 'Theme Restaurant',
#       'pluralName': 'Theme Restaurants',
#       'shortName': 'Theme Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '5a7c3e079de23b294a2c4117',
#     'name': 'Restaurant | Adelaide',
#     'location': {'address': '325 Bay St (31st floor)',
#      'lat': 43.649563,
#      'lng': -79.38059,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649563,
#        'lng': -79.38059}],
#      'distance': 720,
#      'postalCode': 'M5H',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['325 Bay St (31st floor)',
#       'Toronto ON M5H',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4ae9ef82f964a520cbb721e3',
#     'name': 'Alio Restaurant & Wine Bar',
#     'location': {'address': '108 Dundas St W',
#      'crossStreet': 'at Bay St.',
#      'lat': 43.65565507065502,
#      'lng': -79.3841236014983,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65565507065502,
#        'lng': -79.3841236014983}],
#      'distance': 193,
#      'postalCode': 'M5G 1C3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['108 Dundas St W (at Bay St.)',
#       'Toronto ON M5G 1C3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '539c6f13498e06f4cc765165',
#     'name': 'The Elm Tree Restaurant',
#     'location': {'address': '43 Elm St',
#      'crossStreet': 'Bay',
#      'lat': 43.65739749535259,
#      'lng': -79.38376054171513,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65739749535259,
#        'lng': -79.38376054171513}],
#      'distance': 357,
#      'postalCode': 'M5G 1H1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['43 Elm St (Bay)', 'Toronto ON M5G 1H1', 'Canada']},
#     'categories': [{'id': '52e81612bcbc57f1066b79f9',
#       'name': 'Modern European Restaurant',
#       'pluralName': 'Modern European Restaurants',
#       'shortName': 'Modern European',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '88534436'},
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4fbbb3ace4b01e39077b4d55',
#     'name': 'Akashiro Japanese Restaurant & Bar',
#     'location': {'address': '220 Yonge St.',
#      'crossStreet': 'in Toronto Eaton Centre Urban Eatery',
#      'lat': 43.65596504293232,
#      'lng': -79.38054070644233,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65596504293232,
#        'lng': -79.38054070644233}],
#      'distance': 470,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['220 Yonge St. (in Toronto Eaton Centre Urban Eatery)',
#       'Toronto ON',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'shortName': 'Sushi',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4ad4c060f964a5205cf720e3',
#     'name': 'Lai Wah Heen',
#     'location': {'address': '108 Chestnut St.',
#      'crossStreet': 'Chestnut St & Dundas St',
#      'lat': 43.65503785867478,
#      'lng': -79.38589043402241,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65503785867478,
#        'lng': -79.38589043402241}],
#      'distance': 44,
#      'postalCode': 'M5G 1R3',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['108 Chestnut St. (Chestnut St & Dundas St)',
#       'Toronto ON M5G 1R3',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4ad8a5a7f964a5203c1321e3',
#     'name': 'Little India Restaurant',
#     'location': {'address': '255 Queen St. W',
#      'crossStreet': 'Queen and University',
#      'lat': 43.65031880877208,
#      'lng': -79.38899760320798,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65031880877208,
#        'lng': -79.38899760320798}],
#      'distance': 537,
#      'postalCode': 'M5V 1Z4',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['255 Queen St. W (Queen and University)',
#       'Toronto ON M5V 1Z4',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '57793907'},
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4cffc78a75d3236a3b10e7f7',
#     'name': 'Osgoode Hall Restaurant',
#     'location': {'address': '130 Queen St W',
#      'crossStreet': 'University Ave',
#      'lat': 43.651978959035155,
#      'lng': -79.3850485857013,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651978959035155,
#        'lng': -79.3850485857013}],
#      'distance': 311,
#      'postalCode': 'M5H 2N6',
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['130 Queen St W (University Ave)',
#       'M5H 2N6',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'shortName': 'New American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '5dfaabffbdacac0008c8a53a',
#     'name': 'The Winding Road Restaurant',
#     'location': {'address': '5 Baldwin St',
#      'lat': 43.656013,
#      'lng': -79.392451,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656013,
#        'lng': -79.392451}],
#      'distance': 533,
#      'postalCode': 'M5T 1L1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['5 Baldwin St', 'Toronto ON M5T 1L1', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4ad7929cf964a520500c21e3',
#     'name': 'The Senator Restaurant',
#     'location': {'address': '249 Victoria Street',
#      'crossStreet': 'btwn Dundas St E and Shuter St',
#      'lat': 43.65564091455335,
#      'lng': -79.37919882575557,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65564091455335,
#        'lng': -79.37919882575557}],
#      'distance': 566,
#      'postalCode': 'M5B 1T8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['249 Victoria Street (btwn Dundas St E and Shuter St)',
#       'Toronto ON M5B 1T8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '55585058'},
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4afcc52df964a520b82522e3',
#     'name': 'Donatello Restaurant',
#     'location': {'address': '37 Elm St.',
#      'crossStreet': 'at Bay St.',
#      'lat': 43.657489310288014,
#      'lng': -79.38360495100461,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657489310288014,
#        'lng': -79.38360495100461}],
#      'distance': 372,
#      'postalCode': 'M5G 1H1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['37 Elm St. (at Bay St.)',
#       'Toronto ON M5G 1H1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4b82c671f964a52016e430e3',
#     'name': 'Anoush Restaurant',
#     'location': {'address': '250 Dundas St W',
#      'lat': 43.654588,
#      'lng': -79.389692,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654588,
#        'lng': -79.389692}],
#      'distance': 289,
#      'postalCode': 'M5T 2Z5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['250 Dundas St W', 'Toronto ON M5T 2Z5', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4edbccaaf9abeea3db5268df',
#     'name': 'Terrace Restaurant at Elmwood',
#     'location': {'lat': 43.65610066909799,
#      'lng': -79.38148016065777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65610066909799,
#        'lng': -79.38148016065777}],
#      'distance': 404,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'shortName': 'American',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '53ae6660498e1ac3c1282743',
#     'name': 'Castries Bar & Five Way Restaurant',
#     'location': {'lat': 43.654727935791016,
#      'lng': -79.38092803955078,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654727935791016,
#        'lng': -79.38092803955078}],
#      'distance': 416,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'shortName': 'Caribbean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4c12b8ba82a3c9b6083ffaf8',
#     'name': 'Mt. Fuji Japanese Restaurant',
#     'location': {'lat': 43.658555,
#      'lng': -79.384992,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658555,
#        'lng': -79.384992}],
#      'distance': 441,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '4ddd83c788779c82beb061fc',
#     'name': "Ali Baba's",
#     'location': {'address': '199 Dundas St. W',
#      'crossStreet': 'at Centre Ave.',
#      'lat': 43.65491647880546,
#      'lng': -79.38717216891472,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65491647880546,
#        'lng': -79.38717216891472}],
#      'distance': 90,
#      'postalCode': 'M5g 1c8',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['199 Dundas St. W (at Centre Ave.)',
#       'Toronto ON M5g 1c8',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '5834c90e110d032f3217f899',
#     'name': 'Maezo Restaurant & Bar',
#     'location': {'address': '67 Richmond Street West',
#      'crossStreet': 'Richmond and Bay Street',
#      'lat': 43.651090520885205,
#      'lng': -79.38184261322021,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651090520885205,
#        'lng': -79.38184261322021}],
#      'distance': 525,
#      'postalCode': 'M5H 1Z5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['67 Richmond Street West (Richmond and Bay Street)',
#       'Toronto ON M5H 1Z5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '369067217'},
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '5b7618541ffe97002c1a13ae',
#     'name': 'Maezo Restaurant',
#     'location': {'address': '67 Richmond St West',
#      'lat': 43.6513954168839,
#      'lng': -79.38188786532692,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6513954168839,
#        'lng': -79.38188786532692}],
#      'distance': 497,
#      'postalCode': 'M5H 1W2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['67 Richmond St West',
#       'Toronto ON M5H 1W2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False},
#    {'id': '5165c333e4b07a7ad88d8a69',
#     'name': "Joe's Indian Restaurant",
#     'location': {'lat': 43.65814977325445,
#      'lng': -79.38156263736568,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65814977325445,
#        'lng': -79.38156263736568}],
#      'distance': 532,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1579746988',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d14e941735', 'name': 'A...    False
# 1  [{'id': '4bf58dd8d48988d1d2941735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...    False
# 4  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
#
#                          id     location.address location.cc location.city  \
# 0  4ad4c05ff964a52048f720e3  110 Chestnut Street          CA       Toronto
# 1  4ae4b055f964a520229d21e3  143 Dundas St. West          CA       Toronto
# 2  52a7ae41498eed3af4d0a3fa    126 Elizabeth St.          CA       Toronto
# 3  4b2027b5f964a520f82d24e3      195 Dundas St W          CA       Toronto
# 4  4b295e10f964a520ba9d24e3        14 Queen St W          CA       Toronto
#
#   location.country location.crossStreet  location.distance  \
# 0           Canada                  NaN                 27
# 1           Canada                  NaN                103
# 2           Canada           Dundas St.                 91
# 3           Canada    at University Ave                 84
# 4           Canada                  NaN                524
#
#                            location.formattedAddress  \
# 0  [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1          [143 Dundas St. West, Toronto ON, Canada]
# 2  [126 Elizabeth St. (Dundas St.), Toronto ON, C...
# 3  [195 Dundas St W (at University Ave), Toronto ...
# 4        [14 Queen St W, Toronto ON M5H 3X4, Canada]
#
#                              location.labeledLatLngs  location.lat  \
# 0  [{'label': 'display', 'lat': 43.65488413420439...     43.654884
# 1  [{'label': 'display', 'lat': 43.65538110598594...     43.655381
# 2  [{'label': 'display', 'lat': 43.65528126342919...     43.655281
# 3  [{'label': 'display', 'lat': 43.65492521335936...     43.654925
# 4  [{'label': 'display', 'lat': 43.65261436174172...     43.652614
#
#    location.lng location.postalCode location.state  \
# 0    -79.385931             M5G 1R3             ON
# 1    -79.385270                 NaN             ON
# 2    -79.385337                 NaN             ON
# 3    -79.387089             M5G 1C7             ON
# 4    -79.380231             M5H 3X4             ON
#
#                                   name    referralId venuePage.id
# 0      Hemispheres Restaurant & Bistro  v-1579746988          NaN
# 1      Kyoto House Japanese Restaurant  v-1579746988          NaN
# 2         Yueh Tung Chinese Restaurant  v-1579746988          NaN
# 3        Hong Shing Chinese Restaurant  v-1579746988     60327598
# 4  Richtree Natural Market Restaurants  v-1579746988          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                              name                  categories  \
# 0                 Hemispheres Restaurant & Bistro         American Restaurant
# 1                 Kyoto House Japanese Restaurant            Sushi Restaurant
# 2                    Yueh Tung Chinese Restaurant          Chinese Restaurant
# 3                   Hong Shing Chinese Restaurant          Chinese Restaurant
# 4             Richtree Natural Market Restaurants                  Restaurant
# 5                                 Cali Restaurant       Vietnamese Restaurant
# 6                      Wah Too Seafood Restaurant          Chinese Restaurant
# 7                               Tundra Restaurant                  Restaurant
# 8                         New Treasure Restaurant          Dim Sum Restaurant
# 9                      Hendricks Restaurant & Bar                  Restaurant
# 10                               Adega Restaurant                  Restaurant
# 11  Spring Rolls | Japanese Restaurant in Toronto            Theme Restaurant
# 12                          Restaurant | Adelaide                  Restaurant
# 13                     Alio Restaurant & Wine Bar          Italian Restaurant
# 14                        The Elm Tree Restaurant  Modern European Restaurant
# 15             Akashiro Japanese Restaurant & Bar            Sushi Restaurant
# 16                                   Lai Wah Heen          Chinese Restaurant
# 17                        Little India Restaurant           Indian Restaurant
# 18                        Osgoode Hall Restaurant     New American Restaurant
# 19                    The Winding Road Restaurant          Chinese Restaurant
# 20                         The Senator Restaurant                       Diner
# 21                           Donatello Restaurant          Italian Restaurant
# 22                              Anoush Restaurant                  Restaurant
# 23                  Terrace Restaurant at Elmwood         American Restaurant
# 24             Castries Bar & Five Way Restaurant        Caribbean Restaurant
# 25                   Mt. Fuji Japanese Restaurant         Japanese Restaurant
# 26                                     Ali Baba's   Middle Eastern Restaurant
# 27                         Maezo Restaurant & Bar           Indian Restaurant
# 28                               Maezo Restaurant           Indian Restaurant
# 29                        Joe's Indian Restaurant           Indian Restaurant
#
#                      address  cc     city country  \
# 0        110 Chestnut Street  CA  Toronto  Canada
# 1        143 Dundas St. West  CA  Toronto  Canada
# 2          126 Elizabeth St.  CA  Toronto  Canada
# 3            195 Dundas St W  CA  Toronto  Canada
# 4              14 Queen St W  CA  Toronto  Canada
# 5          179 Dundas St. W.  CA  Toronto  Canada
# 6             56 Centre Ave.  CA  Toronto  Canada
# 7   145 Richmond Street West  CA  Toronto  Canada
# 8            150 Dundas St W  CA  Toronto  Canada
# 9            Yonge And Queen  CA  Toronto  Canada
# 10                 33 Elm St  CA  Toronto  Canada
# 11    40 Dundas St W Box 36,  CA  Toronto  Canada
# 12   325 Bay St (31st floor)  CA  Toronto  Canada
# 13           108 Dundas St W  CA  Toronto  Canada
# 14                 43 Elm St  CA  Toronto  Canada
# 15             220 Yonge St.  CA  Toronto  Canada
# 16          108 Chestnut St.  CA  Toronto  Canada
# 17           255 Queen St. W  CA  Toronto  Canada
# 18            130 Queen St W  CA      NaN  Canada
# 19              5 Baldwin St  CA  Toronto  Canada
# 20       249 Victoria Street  CA  Toronto  Canada
# 21                37 Elm St.  CA  Toronto  Canada
# 22           250 Dundas St W  CA  Toronto  Canada
# 23                       NaN  CA      NaN  Canada
# 24                       NaN  CA      NaN  Canada
# 25                       NaN  CA  Toronto  Canada
# 26          199 Dundas St. W  CA  Toronto  Canada
# 27   67 Richmond Street West  CA  Toronto  Canada
# 28       67 Richmond St West  CA  Toronto  Canada
# 29                       NaN  CA      NaN  Canada
#
#                              crossStreet  distance  \
# 0                                    NaN        27
# 1                                    NaN       103
# 2                             Dundas St.        91
# 3                      at University Ave        84
# 4                                    NaN       524
# 5                            at Chestnut        49
# 6                                    NaN        91
# 7                         Hilton Toronto       520
# 8                           at Elizabeth        99
# 9                                    NaN       533
# 10                             at Bay St       381
# 11                                   NaN       263
# 12                                   NaN       720
# 13                            at Bay St.       193
# 14                                   Bay       357
# 15  in Toronto Eaton Centre Urban Eatery       470
# 16               Chestnut St & Dundas St        44
# 17                  Queen and University       537
# 18                        University Ave       311
# 19                                   NaN       533
# 20        btwn Dundas St E and Shuter St       566
# 21                            at Bay St.       372
# 22                                   NaN       289
# 23                                   NaN       404
# 24                                   NaN       416
# 25                                   NaN       441
# 26                        at Centre Ave.        90
# 27               Richmond and Bay Street       525
# 28                                   NaN       497
# 29                                   NaN       532
#
#                                      formattedAddress  \
# 0   [110 Chestnut Street, Toronto ON M5G 1R3, Canada]
# 1           [143 Dundas St. West, Toronto ON, Canada]
# 2   [126 Elizabeth St. (Dundas St.), Toronto ON, C...
# 3   [195 Dundas St W (at University Ave), Toronto ...
# 4         [14 Queen St W, Toronto ON M5H 3X4, Canada]
# 5   [179 Dundas St. W. (at Chestnut), Toronto ON M...
# 6        [56 Centre Ave., Toronto ON M5G 1R5, Canada]
# 7   [145 Richmond Street West (Hilton Toronto), To...
# 8   [150 Dundas St W (at Elizabeth), Toronto ON, C...
# 9       [Yonge And Queen, Toronto ON M5G 2H6, Canada]
# 10  [33 Elm St (at Bay St), Toronto ON M5G 1H1, Ca...
# 11  [40 Dundas St W Box 36,, Toronto ON M5G 2C2, C...
# 12  [325 Bay St (31st floor), Toronto ON M5H, Canada]
# 13  [108 Dundas St W (at Bay St.), Toronto ON M5G ...
# 14      [43 Elm St (Bay), Toronto ON M5G 1H1, Canada]
# 15  [220 Yonge St. (in Toronto Eaton Centre Urban ...
# 16  [108 Chestnut St. (Chestnut St & Dundas St), T...
# 17  [255 Queen St. W (Queen and University), Toron...
# 18  [130 Queen St W (University Ave), M5H 2N6, Can...
# 19         [5 Baldwin St, Toronto ON M5T 1L1, Canada]
# 20  [249 Victoria Street (btwn Dundas St E and Shu...
# 21  [37 Elm St. (at Bay St.), Toronto ON M5G 1H1, ...
# 22      [250 Dundas St W, Toronto ON M5T 2Z5, Canada]
# 23                                           [Canada]
# 24                                           [Canada]
# 25                               [Toronto ON, Canada]
# 26  [199 Dundas St. W (at Centre Ave.), Toronto ON...
# 27  [67 Richmond Street West (Richmond and Bay Str...
# 28  [67 Richmond St West, Toronto ON M5H 1W2, Canada]
# 29                                           [Canada]
#
#                                        labeledLatLngs        lat        lng  \
# 0   [{'label': 'display', 'lat': 43.65488413420439...  43.654884 -79.385931
# 1   [{'label': 'display', 'lat': 43.65538110598594...  43.655381 -79.385270
# 2   [{'label': 'display', 'lat': 43.65528126342919...  43.655281 -79.385337
# 3   [{'label': 'display', 'lat': 43.65492521335936...  43.654925 -79.387089
# 4   [{'label': 'display', 'lat': 43.65261436174172...  43.652614 -79.380231
# 5   [{'label': 'display', 'lat': 43.65506808, 'lng...  43.655068 -79.386375
# 6   [{'label': 'display', 'lat': 43.65483285234745...  43.654833 -79.387206
# 7   [{'label': 'display', 'lat': 43.65000998764964...  43.650010 -79.385608
# 8   [{'label': 'display', 'lat': 43.65538444237565...  43.655384 -79.385362
# 9   [{'label': 'display', 'lat': 43.65341542752959...  43.653415 -79.379698
# 10  [{'label': 'display', 'lat': 43.65751886446546...  43.657519 -79.383462
# 11  [{'label': 'display', 'lat': 43.65610515821675...  43.656105 -79.383495
# 12  [{'label': 'display', 'lat': 43.649563, 'lng':...  43.649563 -79.380590
# 13  [{'label': 'display', 'lat': 43.65565507065502...  43.655655 -79.384124
# 14  [{'label': 'display', 'lat': 43.65739749535259...  43.657397 -79.383761
# 15  [{'label': 'display', 'lat': 43.65596504293232...  43.655965 -79.380541
# 16  [{'label': 'display', 'lat': 43.65503785867478...  43.655038 -79.385890
# 17  [{'label': 'display', 'lat': 43.65031880877208...  43.650319 -79.388998
# 18  [{'label': 'display', 'lat': 43.65197895903515...  43.651979 -79.385049
# 19  [{'label': 'display', 'lat': 43.656013, 'lng':...  43.656013 -79.392451
# 20  [{'label': 'display', 'lat': 43.65564091455335...  43.655641 -79.379199
# 21  [{'label': 'display', 'lat': 43.65748931028801...  43.657489 -79.383605
# 22  [{'label': 'display', 'lat': 43.654588, 'lng':...  43.654588 -79.389692
# 23  [{'label': 'display', 'lat': 43.65610066909799...  43.656101 -79.381480
# 24  [{'label': 'display', 'lat': 43.65472793579101...  43.654728 -79.380928
# 25  [{'label': 'display', 'lat': 43.658555, 'lng':...  43.658555 -79.384992
# 26  [{'label': 'display', 'lat': 43.65491647880546...  43.654916 -79.387172
# 27  [{'label': 'display', 'lat': 43.65109052088520...  43.651091 -79.381843
# 28  [{'label': 'display', 'lat': 43.6513954168839,...  43.651395 -79.381888
# 29  [{'label': 'display', 'lat': 43.65814977325445...  43.658150 -79.381563
#
#    postalCode state                        id
# 0     M5G 1R3    ON  4ad4c05ff964a52048f720e3
# 1         NaN    ON  4ae4b055f964a520229d21e3
# 2         NaN    ON  52a7ae41498eed3af4d0a3fa
# 3     M5G 1C7    ON  4b2027b5f964a520f82d24e3
# 4     M5H 3X4    ON  4b295e10f964a520ba9d24e3
# 5         M5G    ON  4c476d6719fde21e32410876
# 6     M5G 1R5    ON  4c69740b8d22c9284d42b745
# 7     M5H 2L2    ON  50ca02c0245f2d4aa8c2b313
# 8         NaN    ON  4b2a674ef964a52074a824e3
# 9     M5G 2H6    ON  5a8b24b2018cbb6c4ca70dae
# 10    M5G 1H1    ON  4ad4c060f964a52070f720e3
# 11    M5G 2C2    ON  56dd9d68498eb4e5edcb30f9
# 12        M5H    ON  5a7c3e079de23b294a2c4117
# 13    M5G 1C3    ON  4ae9ef82f964a520cbb721e3
# 14    M5G 1H1    ON  539c6f13498e06f4cc765165
# 15        NaN    ON  4fbbb3ace4b01e39077b4d55
# 16    M5G 1R3    ON  4ad4c060f964a5205cf720e3
# 17    M5V 1Z4    ON  4ad8a5a7f964a5203c1321e3
# 18    M5H 2N6   NaN  4cffc78a75d3236a3b10e7f7
# 19    M5T 1L1    ON  5dfaabffbdacac0008c8a53a
# 20    M5B 1T8    ON  4ad7929cf964a520500c21e3
# 21    M5G 1H1    ON  4afcc52df964a520b82522e3
# 22    M5T 2Z5    ON  4b82c671f964a52016e430e3
# 23        NaN   NaN  4edbccaaf9abeea3db5268df
# 24        NaN   NaN  53ae6660498e1ac3c1282743
# 25        NaN    ON  4c12b8ba82a3c9b6083ffaf8
# 26    M5g 1c8    ON  4ddd83c788779c82beb061fc
# 27    M5H 1Z5    ON  5834c90e110d032f3217f899
# 28    M5H 1W2    ON  5b7618541ffe97002c1a13ae
# 29        NaN   NaN  5165c333e4b07a7ad88d8a69

# %%
dataframe_filtered.name
# Out:
# 0                   Hemispheres Restaurant & Bistro
# 1                   Kyoto House Japanese Restaurant
# 2                      Yueh Tung Chinese Restaurant
# 3                     Hong Shing Chinese Restaurant
# 4               Richtree Natural Market Restaurants
# 5                                   Cali Restaurant
# 6                        Wah Too Seafood Restaurant
# 7                                 Tundra Restaurant
# 8                           New Treasure Restaurant
# 9                        Hendricks Restaurant & Bar
# 10                                 Adega Restaurant
# 11    Spring Rolls | Japanese Restaurant in Toronto
# 12                            Restaurant | Adelaide
# 13                       Alio Restaurant & Wine Bar
# 14                          The Elm Tree Restaurant
# 15               Akashiro Japanese Restaurant & Bar
# 16                                     Lai Wah Heen
# 17                          Little India Restaurant
# 18                          Osgoode Hall Restaurant
# 19                      The Winding Road Restaurant
# 20                           The Senator Restaurant
# 21                             Donatello Restaurant
# 22                                Anoush Restaurant
# 23                    Terrace Restaurant at Elmwood
# 24               Castries Bar & Five Way Restaurant
# 25                     Mt. Fuji Japanese Restaurant
# 26                                       Ali Baba's
# 27                           Maezo Restaurant & Bar
# 28                                 Maezo Restaurant
# 29                          Joe's Indian Restaurant
# Name: name, dtype: object

# %% [markdown]
# ### Map of downtown Toronto, showing restaurants within a 500 meter radius of the Doubletree Hotel

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Doubletree Hotel

# add a red circle marker to represent the Doubletree Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Doubletree Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Look at data for the Hemispheres restaurant ###

# %%
venue_id = '4ad4c05ff964a52048f720e3' # ID of Hemispheres Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'hasMenu', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'menu', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'hours', 'popular', 'pageUpdates', 'inbox', 'parent', 'hierarchy', 'attributes', 'bestPhoto', 'colors'])
# {'id': '4ad4c05ff964a52048f720e3',
#  'name': 'Hemispheres Restaurant & Bistro',
#  'contact': {'phone': '4165998000',
#   'formattedPhone': '(416) 599-8000',
#   'twitter': 'methotels'},
#  'location': {'address': '110 Chestnut Street',
#   'lat': 43.65488413420439,
#   'lng': -79.38593077371578,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 43.65488413420439,
#     'lng': -79.38593077371578}],
#   'postalCode': 'M5G 1R3',
#   'cc': 'CA',
#   'city': 'Toronto',
#   'state': 'ON',
#   'country': 'Canada',
#   'formattedAddress': ['110 Chestnut Street', 'Toronto ON M5G 1R3', 'Canada']},
#  'canonicalUrl': 'https://foursquare.com/v/hemispheres-restaurant--bistro/4ad4c05ff964a52048f720e3',
#  'categories': [{'id': '4bf58dd8d48988d14e941735',
#    'name': 'American Restaurant',
#    'pluralName': 'American Restaurants',
#    'shortName': 'American',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': True,
#  'stats': {'tipCount': 5},
#  'url': 'http://metropolitan.com/hemis/',
#  'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'},
#  'hasMenu': True,
#  'likes': {'count': 10,
#   'groups': [{'type': 'others', 'count': 10, 'items': []}],
#   'summary': '10 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 6.7,
#  'ratingColor': 'FFC800',
#  'ratingSignals': 19,
#  'menu': {'type': 'Menu',
#   'label': 'Menu',
#   'anchor': 'View Menu',
#   'url': 'https://foursquare.com/v/hemispheres-restaurant--bistro/4ad4c05ff964a52048f720e3/menu',
#   'mobileUrl': 'https://foursquare.com/v/4ad4c05ff964a52048f720e3/device_menu'},
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 28,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 28,
#     'items': [{'id': '5d7b93f4a1894900081e277e',
#       'createdAt': 1568379892,
#       'source': {'name': 'Swarm for Android',
#        'url': 'https://www.swarmapp.com'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/3958603_4EgsDbbekmHyNDBBmnPS56BWMIS8Q1P6UzrlG9t-KlM.jpg',
#       'width': 1900,
#       'height': 1425,
#       'user': {'id': '3958603',
#        'firstName': 'Martin',
#        'lastName': 'S',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/3958603_5fFzMRbd_oLAKOXFYfwY0bkzvBIdBa3-aySKEBcF4JBE1_4q6Pz1PbZLBaHx2nvu32aJDfGob.jpg'}},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 0, 'items': []},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1255456863,
#  'tips': {'count': 5,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 5,
#     'items': [{'id': '587776e104ab1a1578e5d8be',
#       'createdAt': 1484224225,
#       'text': "Breakfast includes everything you'd expect, plus some surprises! Do not be afraid to try something new.",
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/587776e104ab1a1578e5d8be',
#       'lang': 'en',
#       'likes': {'count': 0, 'groups': []},
#       'logView': True,
#       'agreeCount': 0,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '942918',
#        'firstName': 'Moe',
#        'lastName': 'D',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/CXCI54HBAGPXJ0SR.jpg'}},
#       'authorInteractionType': 'liked'}]}]},
#  'shortUrl': 'http://4sq.com/c6LKfC',
#  'timeZone': 'America/Toronto',
#  'listed': {'count': 2,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 2,
#     'items': [{'id': '4fefbf2ae4b0c664a6e07155',
#       'name': 'Summerlicious',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '22329397',
#        'firstName': 'Antonella',
#        'lastName': 'Z',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/N5YTFYBROX1NTCUC.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/tucazan/list/summerlicious',
#       'canonicalUrl': 'https://foursquare.com/tucazan/list/summerlicious',
#       'createdAt': 1341112106,
#       'updatedAt': 1343832674,
#       'followers': {'count': 0},
#       'listItems': {'count': 1,
#        'items': [{'id': 'v4ad4c05ff964a52048f720e3',
#          'createdAt': 1341112106}]}},
#      {'id': '50a5bd43e4b052420c35e45c',
#       'name': 'Toronto',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '41510324',
#        'firstName': 'Nicola',
#        'lastName': 'C',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/QJYQDDH5VLQGLEKH.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/nicolachivers/list/toronto',
#       'canonicalUrl': 'https://foursquare.com/nicolachivers/list/toronto',
#       'createdAt': 1353039171,
#       'updatedAt': 1380558491,
#       'followers': {'count': 0},
#       'listItems': {'count': 91,
#        'items': [{'id': 'v4ad4c05ff964a52048f720e3',
#          'createdAt': 1353042668}]}}]}]},
#  'hours': {'status': 'Open until Midnight',
#   'richStatus': {'entities': [], 'text': 'Open until Midnight'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'dayData': [],
#   'timeframes': [{'days': 'Mon–Sun',
#     'includesToday': True,
#     'open': [{'renderedTime': '6:30 AM–Midnight'}],
#     'segments': []}]},
#  'popular': {'status': 'Likely open',
#   'richStatus': {'entities': [], 'text': 'Likely open'},
#   'isOpen': True,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '7:00 AM–10:00 AM'},
#      {'renderedTime': 'Noon–1:00 PM'},
#      {'renderedTime': '5:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': '7:00 AM–2:00 PM'},
#      {'renderedTime': '4:00 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '8:00 AM–2:00 PM'},
#      {'renderedTime': '7:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': '7:00 AM–Noon'},
#      {'renderedTime': '2:00 PM–3:00 PM'},
#      {'renderedTime': '6:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '7:00 AM–11:00 AM'},
#      {'renderedTime': '7:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': '7:00 AM–11:00 AM'},
#      {'renderedTime': '6:00 PM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '7:00 AM–11:00 AM'},
#      {'renderedTime': '1:00 PM–2:00 PM'},
#      {'renderedTime': '5:00 PM–11:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'parent': {'id': '52ce14b0498e50457ce11780',
#   'name': 'DoubleTree by Hilton Hotel Toronto Downtown',
#   'location': {'address': '108 Chestnut Street',
#    'crossStreet': 'Dundas St W',
#    'lat': 43.6546083,
#    'lng': -79.3859415,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.6546083,
#      'lng': -79.3859415}],
#    'postalCode': 'M5G 1R3',
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['108 Chestnut Street (Dundas St W)',
#     'Toronto ON M5G 1R3',
#     'Canada']},
#   'categories': [{'id': '4bf58dd8d48988d1fa931735',
#     'name': 'Hotel',
#     'pluralName': 'Hotels',
#     'shortName': 'Hotel',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#      'suffix': '.png'},
#     'primary': True}]},
#  'hierarchy': [{'name': 'DoubleTree by Hilton Hotel Toronto Downtown',
#    'lang': 'en',
#    'id': '52ce14b0498e50457ce11780',
#    'canonicalUrl': 'https://foursquare.com/v/doubletree-by-hilton-hotel-toronto-downtown/52ce14b0498e50457ce11780'}],
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$', 'priceTier': 1}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 5,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'Yes'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'No'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Dinner, Breakfast & more',
#     'count': 8,
#     'items': [{'displayName': 'Breakfast', 'displayValue': 'Breakfast'},
#      {'displayName': 'Brunch', 'displayValue': 'Brunch'},
#      {'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'}]},
#    {'type': 'diningOptions',
#     'name': 'Dining Options',
#     'count': 5,
#     'items': [{'displayName': 'Delivery', 'displayValue': 'No Delivery'}]}]},
#  'bestPhoto': {'id': '5d7b93f4a1894900081e277e',
#   'createdAt': 1568379892,
#   'source': {'name': 'Swarm for Android', 'url': 'https://www.swarmapp.com'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/3958603_4EgsDbbekmHyNDBBmnPS56BWMIS8Q1P6UzrlG9t-KlM.jpg',
#   'width': 1900,
#   'height': 1425,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '5d7b93f4a1894900081e277e',
#    'value': -7823168},
#   'highlightTextColor': {'photoId': '5d7b93f4a1894900081e277e',
#    'value': -16777216},
#   'algoVersion': 3}}

# %% [markdown]
# ### Rating data for the Hemispheres restaurant ###

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.7

# %% [markdown]
# ### Look at data for the Yueh Tang restaurant ###

# %%
venue_id = '52a7ae41498eed3af4d0a3fa' # ID of Yueh Tang Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'url', 'price', 'likes', 'dislike', 'ok', 'rating', 'ratingColor', 'ratingSignals', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'popular', 'pageUpdates', 'inbox', 'attributes', 'bestPhoto', 'colors'])
# {'id': '52a7ae41498eed3af4d0a3fa',
#  'name': 'Yueh Tung Chinese Restaurant',
#  'contact': {'phone': '4169770933', 'formattedPhone': '(416) 977-0933'},
#  'location': {'address': '126 Elizabeth St.',
#   'crossStreet': 'Dundas St.',
#   'lat': 43.655281263429195,
#   'lng': -79.3853365267765,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': 43.655281263429195,
#     'lng': -79.3853365267765}],
#   'cc': 'CA',
#   'city': 'Toronto',
#   'state': 'ON',
#   'country': 'Canada',
#   'formattedAddress': ['126 Elizabeth St. (Dundas St.)',
#    'Toronto ON',
#    'Canada']},
#  'canonicalUrl': 'https://foursquare.com/v/yueh-tung-chinese-restaurant/52a7ae41498eed3af4d0a3fa',
#  'categories': [{'id': '4bf58dd8d48988d145941735',
#    'name': 'Chinese Restaurant',
#    'pluralName': 'Chinese Restaurants',
#    'shortName': 'Chinese',
#    'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#     'suffix': '.png'},
#    'primary': True}],
#  'verified': False,
#  'stats': {'tipCount': 10},
#  'url': 'http://www.yuehtungrestaurant.com',
#  'price': {'tier': 1, 'message': 'Cheap', 'currency': '$'},
#  'likes': {'count': 33,
#   'groups': [{'type': 'others', 'count': 33, 'items': []}],
#   'summary': '33 Likes'},
#  'dislike': False,
#  'ok': False,
#  'rating': 7.9,
#  'ratingColor': 'C5DE35',
#  'ratingSignals': 50,
#  'allowMenuUrlEdit': True,
#  'beenHere': {'count': 0,
#   'unconfirmedCount': 0,
#   'marked': False,
#   'lastCheckinExpiredAt': 0},
#  'specials': {'count': 0, 'items': []},
#  'photos': {'count': 20,
#   'groups': [{'type': 'venue',
#     'name': 'Venue photos',
#     'count': 20,
#     'items': [{'id': '52a7b00f498ed11dc1af45ed',
#       'createdAt': 1386721295,
#       'source': {'name': 'Foursquare for Android',
#        'url': 'https://foursquare.com/download/#/android'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/17216351_R_WKnNMz_ZJuNLYsPiL-oGRXCxuBeLH8QxCBD3rkjQA.jpg',
#       'width': 960,
#       'height': 720,
#       'user': {'id': '17216351',
#        'firstName': 'Betty',
#        'lastName': 'K',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/L4I2VWZO33JDDH5X.jpg'}},
#       'visibility': 'public'}]}]},
#  'reasons': {'count': 1,
#   'items': [{'summary': 'Lots of people like this place',
#     'type': 'general',
#     'reasonName': 'rawLikesReason'}]},
#  'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []},
#  'createdAt': 1386720833,
#  'tips': {'count': 10,
#   'groups': [{'type': 'others',
#     'name': 'All tips',
#     'count': 10,
#     'items': [{'id': '5432b9f5498eed5f9fefd470',
#       'createdAt': 1412610549,
#       'text': 'Chili chicken is good. However not the style I am used to. Fried general tao  style rather than the sauted style that I am used ro.',
#       'type': 'user',
#       'canonicalUrl': 'https://foursquare.com/item/5432b9f5498eed5f9fefd470',
#       'lang': 'en',
#       'likes': {'count': 1,
#        'groups': [{'type': 'others',
#          'count': 1,
#          'items': [{'id': '99368673',
#            'firstName': 'IAM Group',
#            'lastName': 'L',
#            'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#             'suffix': '/99368673-3QBQSIW2TBGKBMK4.jpg'}}]}],
#        'summary': '1 like'},
#       'logView': True,
#       'agreeCount': 1,
#       'disagreeCount': 0,
#       'todo': {'count': 0},
#       'user': {'id': '75532079',
#        'firstName': 'Robert',
#        'lastName': 'G',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/blank_boy.png',
#         'default': True}},
#       'authorInteractionType': 'liked'}]}]},
#  'shortUrl': 'http://4sq.com/1aT9hvS',
#  'timeZone': 'America/Toronto',
#  'listed': {'count': 15,
#   'groups': [{'type': 'others',
#     'name': 'Lists from other people',
#     'count': 15,
#     'items': [{'id': '5ca04c062b9844002ccbc893',
#       'name': 'Must try near Dundas Square',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '358760441',
#        'firstName': 'Aleksasha',
#        'lastName': 'G',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/358760441_La6CLQ66_vqbwyoQ5rU0esIY9LBr9ii9DsErr-NfN_uAZh5NMKOTX2H-nhofd2z0tTjZmo24R.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/358760441/list/must-try-near-dundas-square',
#       'canonicalUrl': 'https://foursquare.com/user/358760441/list/must-try-near-dundas-square',
#       'createdAt': 1554009094,
#       'updatedAt': 1562534243,
#       'followers': {'count': 0},
#       'listItems': {'count': 9,
#        'items': [{'id': 'v52a7ae41498eed3af4d0a3fa',
#          'createdAt': 1554009300}]}},
#      {'id': '5022775fe4b013b03e9d3940',
#       'name': 'Favorites',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '31962478',
#        'firstName': 'Karen',
#        'lastName': 'D',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/31F0CG0SLMV5A25B.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/specialkdmd/list/favorites',
#       'canonicalUrl': 'https://foursquare.com/specialkdmd/list/favorites',
#       'createdAt': 1344436063,
#       'updatedAt': 1577815711,
#       'followers': {'count': 3},
#       'listItems': {'count': 199,
#        'items': [{'id': 'v52a7ae41498eed3af4d0a3fa',
#          'createdAt': 1418144286}]}},
#      {'id': '50ce2954e4b044ef72f22fc7',
#       'name': 'Tried more',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '31962478',
#        'firstName': 'Karen',
#        'lastName': 'D',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/31F0CG0SLMV5A25B.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/specialkdmd/list/tried-more',
#       'canonicalUrl': 'https://foursquare.com/specialkdmd/list/tried-more',
#       'createdAt': 1355688276,
#       'updatedAt': 1494330673,
#       'followers': {'count': 2},
#       'listItems': {'count': 201,
#        'items': [{'id': 'v52a7ae41498eed3af4d0a3fa',
#          'createdAt': 1418144290}]}},
#      {'id': '4f183798e4b0333427a63f9c',
#       'name': 'Toronto',
#       'description': '',
#       'type': 'others',
#       'user': {'id': '1988380',
#        'firstName': 'Hkling',
#        'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#         'suffix': '/1988380-LO3HCQPH4ZP2EXAT.jpg'}},
#       'editable': False,
#       'public': True,
#       'collaborative': False,
#       'url': '/user/1988380/list/toronto',
#       'canonicalUrl': 'https://foursquare.com/user/1988380/list/toronto',
#       'createdAt': 1326987160,
#       'updatedAt': 1579257057,
#       'photo': {'id': '528c664911d2932b228fba7a',
#        'createdAt': 1384932937,
#        'prefix': 'https://fastly.4sqi.net/img/general/',
#        'suffix': '/11859261_yYcVCvF8wBTAiny-lejUhvhobLPZo1NpeDQvwDc7gSU.jpg',
#        'width': 853,
#        'height': 720,
#        'user': {'id': '11859261',
#         'firstName': 'Val',
#         'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#          'suffix': '/2VUOZYFRV110A5MJ.jpg'}},
#        'visibility': 'public'},
#       'followers': {'count': 12},
#       'listItems': {'count': 177,
#        'items': [{'id': 'v52a7ae41498eed3af4d0a3fa',
#          'createdAt': 1513994350}]}}]}]},
#  'popular': {'isOpen': False,
#   'isLocalHoliday': False,
#   'timeframes': [{'days': 'Today',
#     'includesToday': True,
#     'open': [{'renderedTime': '11:00 AM–2:00 PM'},
#      {'renderedTime': '5:00 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Thu',
#     'open': [{'renderedTime': '11:00 AM–2:00 PM'},
#      {'renderedTime': '6:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Fri',
#     'open': [{'renderedTime': '11:00 AM–11:00 PM'}],
#     'segments': []},
#    {'days': 'Sat',
#     'open': [{'renderedTime': 'Noon–3:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Sun',
#     'open': [{'renderedTime': '1:00 PM–3:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []},
#    {'days': 'Mon',
#     'open': [{'renderedTime': 'Noon–2:00 PM'},
#      {'renderedTime': '5:00 PM–9:00 PM'}],
#     'segments': []},
#    {'days': 'Tue',
#     'open': [{'renderedTime': '11:00 AM–2:00 PM'},
#      {'renderedTime': '5:00 PM–10:00 PM'}],
#     'segments': []}]},
#  'pageUpdates': {'count': 0, 'items': []},
#  'inbox': {'count': 0, 'items': []},
#  'attributes': {'groups': [{'type': 'price',
#     'name': 'Price',
#     'summary': '$',
#     'count': 1,
#     'items': [{'displayName': 'Price', 'displayValue': '$', 'priceTier': 1}]},
#    {'type': 'reservations',
#     'name': 'Reservations',
#     'summary': 'Reservations',
#     'count': 3,
#     'items': [{'displayName': 'Reservations', 'displayValue': 'Yes'}]},
#    {'type': 'payments',
#     'name': 'Credit Cards',
#     'summary': 'Credit Cards',
#     'count': 5,
#     'items': [{'displayName': 'Credit Cards', 'displayValue': 'Yes'}]},
#    {'type': 'outdoorSeating',
#     'name': 'Outdoor Seating',
#     'count': 1,
#     'items': [{'displayName': 'Outdoor Seating', 'displayValue': 'No'}]},
#    {'type': 'serves',
#     'name': 'Menus',
#     'summary': 'Lunch & Dinner',
#     'count': 8,
#     'items': [{'displayName': 'Lunch', 'displayValue': 'Lunch'},
#      {'displayName': 'Dinner', 'displayValue': 'Dinner'}]},
#    {'type': 'drinks',
#     'name': 'Drinks',
#     'summary': 'Cocktails',
#     'count': 5,
#     'items': [{'displayName': 'Cocktails', 'displayValue': 'Cocktails'}]},
#    {'type': 'diningOptions',
#     'name': 'Dining Options',
#     'count': 5,
#     'items': [{'displayName': 'Delivery', 'displayValue': 'No Delivery'}]}]},
#  'bestPhoto': {'id': '52a7b00f498ed11dc1af45ed',
#   'createdAt': 1386721295,
#   'source': {'name': 'Foursquare for Android',
#    'url': 'https://foursquare.com/download/#/android'},
#   'prefix': 'https://fastly.4sqi.net/img/general/',
#   'suffix': '/17216351_R_WKnNMz_ZJuNLYsPiL-oGRXCxuBeLH8QxCBD3rkjQA.jpg',
#   'width': 960,
#   'height': 720,
#   'visibility': 'public'},
#  'colors': {'highlightColor': {'photoId': '52a7b00f498ed11dc1af45ed',
#    'value': -15198184},
#   'highlightTextColor': {'photoId': '52a7b00f498ed11dc1af45ed', 'value': -1},
#   'algoVersion': 3}}

# %% [markdown]
# ### Rating data for the Yueh Tang restaurant ###

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 7.9

# %% [markdown]
# ### Get tips for Yueh Tang ###

# %%
result['response']['venue']['tips']['count']
# Out:
# 5

# %%
## The Yueh Tang Restaurant Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e2906c6fb34b5001bcde9eb'},
#  'response': {'tips': {'count': 10,
#    'items': [{'id': '581bb07fd67c728bae67294f',
#      'createdAt': 1478209663,
#      'text': '30th October 2016 -YUEH TUNG CHINESE RESTAURANT VERY TASTY  FOOD -I LOVED THE CHILLI BEEF & CHILLI FISH YUM YUM👅',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/581bb07fd67c728bae67294f',
#      'photo': {'id': '581bb07fbda2d73777fafdd2',
#       'createdAt': 1478209663,
#       'source': {'name': 'Foursquare for Android',
#        'url': 'https://foursquare.com/download/#/android'},
#       'prefix': 'https://fastly.4sqi.net/img/general/',
#       'suffix': '/159607071_1YLasoAidR7phN5vJv912EVohyInxFAXfvQfTVDs1U8.jpg',
#       'width': 1032,
#       'height': 581,
#       'visibility': 'public'},
#      'photourl': 'https://fastly.4sqi.net/img/general/original/159607071_1YLasoAidR7phN5vJv912EVohyInxFAXfvQfTVDs1U8.jpg',
#      'lang': 'en',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'agreeCount': 0,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '159607071',
#       'firstName': 'Linette',
#       'lastName': 'G',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/159607071_uk2aNYGX_Kb2Ec-fUTAlAjHj6jipgyfqPzNHcVAPj75JUKHFhFc0L2UzSm74ic6dslrNMJhyR.jpg'}},
#      'authorInteractionType': 'liked'}]}}}

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'photo', 'photourl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user', 'authorInteractionType'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
#                                                                                                                text  \
# 0  30th October 2016 -YUEH TUNG CHINESE RESTAURANT VERY TASTY  FOOD -I LOVED THE CHILLI BEEF & CHILLI FISH YUM YUM👅
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  0           0              581bb07fd67c728bae67294f  Linette
#
#   user.lastName  user.gender    user.id
# 0  G            NaN           159607071

# %% [markdown]
# ### Explore area around the Yueh Tang Restaurant location ###

# %%
# Latitude and Longitude of Yueh Tang
latitude = 43.655281
longitude = -79.385337

# %%
# Pass url including location data to Foursquare
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)

# %%
# Load results into JSON file, then print number of points of interest
results = requests.get(url).json()
'There are {} points of interest around the Yueh Tang restaurant.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 points of interest around the Yueh Tang restaurant.'

# %%
# Build items list from JSON results
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '5227bb01498e17bf485e6202',
#   'name': 'Downtown Toronto',
#   'location': {'lat': 43.65323167517444,
#    'lng': -79.38529600606677,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 43.65323167517444,
#      'lng': -79.38529600606677}],
#    'distance': 228,
#    'cc': 'CA',
#    'city': 'Toronto',
#    'state': 'ON',
#    'country': 'Canada',
#    'formattedAddress': ['Toronto ON', 'Canada']},
#   'categories': [{'id': '4f2a25ac4b909258e854f55f',
#     'name': 'Neighborhood',
#     'pluralName': 'Neighborhoods',
#     'shortName': 'Neighborhood',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/neighborhood_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-5227bb01498e17bf485e6202-0'}

# %%
# Build dataframe with normalized JSON data, filtering columns and categories, and cleaning up column headings
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
#                       name                  categories            address  cc  \
# 0  Downtown Toronto         Neighborhood                NaN                CA
# 1  Red Lobster              Seafood Restaurant          20 Dundas St W     CA
# 2  Japango                  Sushi Restaurant            122 Elizabeth St.  CA
# 3  Chatime 日出茶太             Bubble Tea Shop             132 Dundas St W    CA
# 4  MUJI                     Miscellaneous Shop          595 Bay St E       CA
# 5  Rolltation               Japanese Restaurant         207 Dundas St W    CA
# 6  Tsujiri                  Tea Room                    147 Dundas St W    CA
# 7  Sansotei Ramen 三草亭       Ramen Restaurant            179 Dundas St. W   CA
# 8  Poke Guys                Poke Place                  112 Elizabeth St   CA
# 9  The Elm Tree Restaurant  Modern European Restaurant  43 Elm St          CA
#
#       city country                      crossStreet  distance  \
# 0  Toronto  Canada  NaN                              228
# 1  Toronto  Canada  at Bay St                        180
# 2  Toronto  Canada  at Dundas St. W                  13
# 3  Toronto  Canada  btwn Bay & University            60
# 4  Toronto  Canada  at Dundas St W                   184
# 5  Toronto  Canada  at University Ave                172
# 6  Toronto  Canada  at Elizabeth St                  10
# 7  Toronto  Canada  btwn Centre Ave. & Chestnut St.  94
# 8  Toronto  Canada  at Dundas St W                   48
# 9  Toronto  Canada  Bay                              267
#
#                                                                    formattedAddress  \
# 0  [Toronto ON, Canada]
# 1  [20 Dundas St W (at Bay St), Toronto ON M5G 2C2, Canada]
# 2  [122 Elizabeth St. (at Dundas St. W), Toronto ON M5G 1P5, Canada]
# 3  [132 Dundas St W (btwn Bay & University), Toronto ON M5G 1C3, Canada]
# 4  [595 Bay St E (at Dundas St W), Toronto ON, Canada]
# 5  [207 Dundas St W (at University Ave), Toronto ON M5G 1C8, Canada]
# 6  [147 Dundas St W (at Elizabeth St), Toronto ON M5G 1P5, Canada]
# 7  [179 Dundas St. W (btwn Centre Ave. & Chestnut St.), Toronto ON M5G 1Z8, Canada]
# 8  [112 Elizabeth St (at Dundas St W), Toronto ON M5G 1P5, Canada]
# 9  [43 Elm St (Bay), Toronto ON M5G 1H1, Canada]
#
#                                                                  labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 43.65323167517444, 'lng': -79.38529600606677}]
# 1  [{'label': 'display', 'lat': 43.656328, 'lng': -79.383621}]
# 2  [{'label': 'display', 'lat': 43.65526771691681, 'lng': -79.38516506734886}]
# 3  [{'label': 'display', 'lat': 43.65554164147378, 'lng': -79.38468427043244}]
# 4  [{'label': 'display', 'lat': 43.656024, 'lng': -79.383284}]
# 5  [{'label': 'display', 'lat': 43.65491791857301, 'lng': -79.3874242454196}]
# 6  [{'label': 'display', 'lat': 43.65537430780922, 'lng': -79.38535434742991}]
# 7  [{'label': 'display', 'lat': 43.655157467561246, 'lng': -79.38650067479335}]
# 8  [{'label': 'display', 'lat': 43.65489527525682, 'lng': -79.38505238381624}]
# 9  [{'label': 'display', 'lat': 43.65739749535259, 'lng': -79.38376054171513}]
#
#          lat        lng neighborhood postalCode state  \
# 0  43.653232 -79.385296  NaN          NaN        ON
# 1  43.656328 -79.383621  NaN          M5G 2C2    ON
# 2  43.655268 -79.385165  NaN          M5G 1P5    ON
# 3  43.655542 -79.384684  NaN          M5G 1C3    ON
# 4  43.656024 -79.383284  NaN          NaN        ON
# 5  43.654918 -79.387424  NaN          M5G 1C8    ON
# 6  43.655374 -79.385354  NaN          M5G 1P5    ON
# 7  43.655157 -79.386501  NaN          M5G 1Z8    ON
# 8  43.654895 -79.385052  NaN          M5G 1P5    ON
# 9  43.657397 -79.383761  NaN          M5G 1H1    ON
#
#                          id
# 0  5227bb01498e17bf485e6202
# 1  4ae3398ff964a520ed9121e3
# 2  4ae7b27df964a52068ad21e3
# 3  4e2284b11fc7c0ef9857d143
# 4  5479da4f498e8569fb44985c
# 5  5773f01f498e98371390bdfd
# 6  56ccd5cfcd1069ca160a797e
# 7  504bbf2ce4b0168121235cbe
# 8  57bcd3b7498e652a678d0378
# 9  539c6f13498e06f4cc765165

# %% [markdown]
# ### Build and display map using Folium to show points of interest close to the Yueh Tang restaurant ###

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Yueh Tang Chinese Restaurant',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Get trending venues, if any are found from the area around the Yueh Tang ###

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e290719b9a389001bb364a7'},
#  'response': {'venues': [{'id': '4b155081f964a520b4b023e3',
#     'name': 'Scotiabank Arena',
#     'location': {'address': '40 Bay St',
#      'lat': 43.64344617535107,
#      'lng': -79.37903988889991,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64344617535107,
#        'lng': -79.37903988889991}],
#      'distance': 1411,
#      'postalCode': 'M5J 2X2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['40 Bay St', 'Toronto ON M5J 2X2', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d18b941735',
#       'name': 'Basketball Stadium',
#       'pluralName': 'Basketball Stadiums',
#       'shortName': 'Basketball',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_basketball_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '33431410'}}]}}

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %% [markdown]
# ### Display results and area map of trending venues query, with message if no values are found ###

# %%
# display trending venues
trending_venues_df
# Out:
#                name          categories  location.distance location.city  \
# 0  Scotiabank Arena  Basketball Stadium  1411               Toronto
#
#   location.postalCode location.state location.country  location.lat  \
# 0  M5J 2X2             ON             Canada           43.643446
#
#    location.lng
# 0 -79.37904

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Ecco',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'
